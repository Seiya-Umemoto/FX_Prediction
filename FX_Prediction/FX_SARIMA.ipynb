# %%
import pandas as pd
import numpy as np
# %matplotlib inline

df = pd.read_csv('2018-08-14_06_00_00_2020-01-02_19_00_00_H1.csv', index_col='time', parse_dates=True)
df.drop(columns=['complete'],inplace=True)
df.plot(y=['open','close'],figsize=(15,10));

# %%
periods = 8619
df.index = pd.date_range(start='2018-08-14 06:00:00',freq='H',periods=periods)
df.index
# Out:
# DatetimeIndex(['2018-08-14 06:00:00', '2018-08-14 07:00:00',
#                '2018-08-14 08:00:00', '2018-08-14 09:00:00',
#                '2018-08-14 10:00:00', '2018-08-14 11:00:00',
#                '2018-08-14 12:00:00', '2018-08-14 13:00:00',
#                '2018-08-14 14:00:00', '2018-08-14 15:00:00',
#                ...
#                '2019-08-07 23:00:00', '2019-08-08 00:00:00',
#                '2019-08-08 01:00:00', '2019-08-08 02:00:00',
#                '2019-08-08 03:00:00', '2019-08-08 04:00:00',
#                '2019-08-08 05:00:00', '2019-08-08 06:00:00',
#                '2019-08-08 07:00:00', '2019-08-08 08:00:00'],
#               dtype='datetime64[ns]', length=8619, freq='H')

# %%
# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = df[['open']]
df
# Out:
#                         open
# 2018-08-14 06:00:00  110.687
# 2018-08-14 07:00:00  110.748
# 2018-08-14 08:00:00  110.722
# 2018-08-14 09:00:00  110.633
# 2018-08-14 10:00:00  110.790
# ...                      ...
# 2019-08-08 04:00:00  108.744
# 2019-08-08 05:00:00  108.710
# 2019-08-08 06:00:00  108.782
# 2019-08-08 07:00:00  108.783
# 2019-08-08 08:00:00  108.836
#
# [8619 rows x 1 columns]

# %%
result = seasonal_decompose(df, model='add')
result.plot();

# %%
# For SARIMA Orders we set seasonal=True and pass in an m value
auto_arima(df,seasonal=True,m=24).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8619
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                9228.398
# Date:                Sat, 01 Feb 2020   AIC                         -18454.797
# Time:                        02:50:40   BIC                         -18447.735
# Sample:                             0   HQIC                        -18452.389
#                                - 8619
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0069   2.64e-05    260.022      0.000       0.007       0.007
# ===================================================================================
# Ljung-Box (Q):                       53.10   Jarque-Bera (JB):            310516.04
# Prob(Q):                              0.08   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.76
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
len(df)
# Out:
# 8619

# %%
import math
# Set one year for testing
train = df.iloc[:math.ceil(periods*0.8)]
test = df.iloc[math.ceil(periods*0.8):]
# train = df.iloc[:1440]
# test = df.iloc[1440:]

# %%
model = SARIMAX(train,order=(0,1,3),seasonal_order=(1,0,1,24))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                               open   No. Observations:                 6896
# Model:             SARIMAX(0, 1, 3)x(1, 0, 1, 24)   Log Likelihood                7063.913
# Date:                            Sat, 01 Feb 2020   AIC                         -14115.826
# Time:                                    02:50:42   BIC                         -14074.795
# Sample:                                08-14-2018   HQIC                        -14101.677
#                                      - 05-28-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0030      0.009     -0.355      0.723      -0.020       0.014
# ma.L2         -0.0306      0.010     -3.205      0.001      -0.049      -0.012
# ma.L3         -0.0094      0.011     -0.873      0.383      -0.030       0.012
# ar.S.L24      -0.0820      1.085     -0.076      0.940      -2.208       2.044
# ma.S.L24       0.0720      1.085      0.066      0.947      -2.055       2.199
# sigma2         0.0075   3.74e-05    201.600      0.000       0.007       0.008
# ===================================================================================
# Ljung-Box (Q):                       47.41   Jarque-Bera (JB):            257371.42
# Prob(Q):                              0.20   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.25   Skew:                            -0.80
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Obtain predicted values
start=len(train)
end=len(train)+len(test)-1
predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('SARIMA(0,1,3)(1,0,1,24) Predictions')

# %%
# Compare predictions to expected values
for i in range(len(predictions)):
    print(f"predicted={predictions[i]:<11.10}, expected={test.iloc[i]}")
# Out:
# predicted=107.9266774, expected=open    107.981
# Name: 2019-05-28 14:00:00, dtype: float64
# predicted=107.9270723, expected=open    107.883
# Name: 2019-05-28 15:00:00, dtype: float64
# predicted=107.9275922, expected=open    107.95
# Name: 2019-05-28 16:00:00, dtype: float64
# predicted=107.927984 , expected=open    107.882
# Name: 2019-05-28 17:00:00, dtype: float64
# predicted=107.9284786, expected=open    107.699
# Name: 2019-05-28 18:00:00, dtype: float64
# predicted=107.9279517, expected=open    107.658
# Name: 2019-05-28 19:00:00, dtype: float64
# predicted=107.9274649, expected=open    107.548
# Name: 2019-05-28 20:00:00, dtype: float64
# predicted=107.927558 , expected=open    107.554
# Name: 2019-05-28 21:00:00, dtype: float64
# predicted=107.9273745, expected=open    107.718
# Name: 2019-05-28 22:00:00, dtype: float64
# predicted=107.927557 , expected=open    107.722
# Name: 2019-05-28 23:00:00, dtype: float64
# predicted=107.9271078, expected=open    107.681
# Name: 2019-05-29 00:00:00, dtype: float64
# predicted=107.9279929, expected=open    107.654
# Name: 2019-05-29 01:00:00, dtype: float64
# predicted=107.9283512, expected=open    107.69
# Name: 2019-05-29 02:00:00, dtype: float64
# predicted=107.9283493, expected=open    107.692
# Name: 2019-05-29 03:00:00, dtype: float64
# predicted=107.92833  , expected=open    107.693
# Name: 2019-05-29 04:00:00, dtype: float64
# predicted=107.9290066, expected=open    107.708
# Name: 2019-05-29 05:00:00, dtype: float64
# predicted=107.9289523, expected=open    107.72
# Name: 2019-05-29 06:00:00, dtype: float64
# predicted=107.9286433, expected=open    107.714
# Name: 2019-05-29 07:00:00, dtype: float64
# predicted=107.928194 , expected=open    107.728
# Name: 2019-05-29 08:00:00, dtype: float64
# predicted=107.9282612, expected=open    107.516
# Name: 2019-05-29 09:00:00, dtype: float64
# predicted=107.9275158, expected=open    107.355
# Name: 2019-05-29 10:00:00, dtype: float64
# predicted=107.9277466, expected=open    107.496
# Name: 2019-05-29 11:00:00, dtype: float64
# predicted=107.9280013, expected=open    107.46
# Name: 2019-05-29 12:00:00, dtype: float64
# predicted=107.9282012, expected=open    107.456
# Name: 2019-05-29 13:00:00, dtype: float64
# predicted=107.9282153, expected=open    107.534
# Name: 2019-05-29 14:00:00, dtype: float64
# predicted=107.9282388, expected=open    107.428
# Name: 2019-05-29 15:00:00, dtype: float64
# predicted=107.9282091, expected=open    107.36
# Name: 2019-05-29 16:00:00, dtype: float64
# predicted=107.928177 , expected=open    107.478
# Name: 2019-05-29 17:00:00, dtype: float64
# predicted=107.9281364, expected=open    107.498
# Name: 2019-05-29 18:00:00, dtype: float64
# predicted=107.9281796, expected=open    107.508
# Name: 2019-05-29 19:00:00, dtype: float64
# predicted=107.9282195, expected=open    107.464
# Name: 2019-05-29 20:00:00, dtype: float64
# predicted=107.9282119, expected=open    107.424
# Name: 2019-05-29 21:00:00, dtype: float64
# predicted=107.9282269, expected=open    107.548
# Name: 2019-05-29 22:00:00, dtype: float64
# predicted=107.928212 , expected=open    107.536
# Name: 2019-05-29 23:00:00, dtype: float64
# predicted=107.9282488, expected=open    107.493
# Name: 2019-05-30 00:00:00, dtype: float64
# predicted=107.9281762, expected=open    107.598
# Name: 2019-05-30 01:00:00, dtype: float64
# predicted=107.9281469, expected=open    107.649
# Name: 2019-05-30 02:00:00, dtype: float64
# predicted=107.928147 , expected=open    107.58
# Name: 2019-05-30 03:00:00, dtype: float64
# predicted=107.9281486, expected=open    107.536
# Name: 2019-05-30 04:00:00, dtype: float64
# predicted=107.9280931, expected=open    107.537
# Name: 2019-05-30 05:00:00, dtype: float64
# predicted=107.9280976, expected=open    107.61
# Name: 2019-05-30 06:00:00, dtype: float64
# predicted=107.9281229, expected=open    107.582
# Name: 2019-05-30 07:00:00, dtype: float64
# predicted=107.9281597, expected=open    107.568
# Name: 2019-05-30 08:00:00, dtype: float64
# predicted=107.9281542, expected=open    107.592
# Name: 2019-05-30 09:00:00, dtype: float64
# predicted=107.9282153, expected=open    107.638
# Name: 2019-05-30 10:00:00, dtype: float64
# predicted=107.9281964, expected=open    107.739
# Name: 2019-05-30 11:00:00, dtype: float64
# predicted=107.9281755, expected=open    107.69
# Name: 2019-05-30 12:00:00, dtype: float64
# predicted=107.9281592, expected=open    107.686
# Name: 2019-05-30 13:00:00, dtype: float64
# predicted=107.928158 , expected=open    107.646
# Name: 2019-05-30 14:00:00, dtype: float64
# predicted=107.9281561, expected=open    107.646
# Name: 2019-05-30 15:00:00, dtype: float64
# predicted=107.9281585, expected=open    107.412
# Name: 2019-05-30 16:00:00, dtype: float64
# predicted=107.9281611, expected=open    107.318
# Name: 2019-05-30 17:00:00, dtype: float64
# predicted=107.9281645, expected=open    107.084
# Name: 2019-05-30 18:00:00, dtype: float64
# predicted=107.9281609, expected=open    107.101
# Name: 2019-05-30 19:00:00, dtype: float64
# predicted=107.9281577, expected=open    107.043
# Name: 2019-05-30 20:00:00, dtype: float64
# predicted=107.9281583, expected=open    107.028
# Name: 2019-05-30 21:00:00, dtype: float64
# predicted=107.928157 , expected=open    107.086
# Name: 2019-05-30 22:00:00, dtype: float64
# predicted=107.9281583, expected=open    107.105
# Name: 2019-05-30 23:00:00, dtype: float64
# predicted=107.9281553, expected=open    107.111
# Name: 2019-05-31 00:00:00, dtype: float64
# predicted=107.9281612, expected=open    107.169
# Name: 2019-05-31 01:00:00, dtype: float64
# predicted=107.9281636, expected=open    107.066
# Name: 2019-05-31 02:00:00, dtype: float64
# predicted=107.9281636, expected=open    107.254
# Name: 2019-05-31 03:00:00, dtype: float64
# predicted=107.9281635, expected=open    107.342
# Name: 2019-05-31 04:00:00, dtype: float64
# predicted=107.928168 , expected=open    107.318
# Name: 2019-05-31 05:00:00, dtype: float64
# predicted=107.9281676, expected=open    107.36
# Name: 2019-05-31 06:00:00, dtype: float64
# predicted=107.9281656, expected=open    107.344
# Name: 2019-05-31 07:00:00, dtype: float64
# predicted=107.9281626, expected=open    107.374
# Name: 2019-05-31 08:00:00, dtype: float64
# predicted=107.928163 , expected=open    107.284
# Name: 2019-05-31 09:00:00, dtype: float64
# predicted=107.928158 , expected=open    107.313
# Name: 2019-05-31 10:00:00, dtype: float64
# predicted=107.9281595, expected=open    107.33
# Name: 2019-05-31 11:00:00, dtype: float64
# predicted=107.9281613, expected=open    107.321
# Name: 2019-05-31 12:00:00, dtype: float64
# predicted=107.9281626, expected=open    107.404
# Name: 2019-05-31 13:00:00, dtype: float64
# predicted=107.9281627, expected=open    107.508
# Name: 2019-05-31 14:00:00, dtype: float64
# predicted=107.9281629, expected=open    107.546
# Name: 2019-05-31 15:00:00, dtype: float64
# predicted=107.9281627, expected=open    107.716
# Name: 2019-05-31 16:00:00, dtype: float64
# predicted=107.9281624, expected=open    107.784
# Name: 2019-05-31 17:00:00, dtype: float64
# predicted=107.9281622, expected=open    107.8
# Name: 2019-05-31 18:00:00, dtype: float64
# predicted=107.9281625, expected=open    107.772
# Name: 2019-05-31 19:00:00, dtype: float64
# predicted=107.9281627, expected=open    107.816
# Name: 2019-05-31 20:00:00, dtype: float64
# predicted=107.9281627, expected=open    107.784
# Name: 2019-05-31 21:00:00, dtype: float64
# predicted=107.9281628, expected=open    107.757
# Name: 2019-05-31 22:00:00, dtype: float64
# predicted=107.9281627, expected=open    107.74
# Name: 2019-05-31 23:00:00, dtype: float64
# predicted=107.9281629, expected=open    107.746
# Name: 2019-06-01 00:00:00, dtype: float64
# predicted=107.9281624, expected=open    107.702
# Name: 2019-06-01 01:00:00, dtype: float64
# predicted=107.9281622, expected=open    107.721
# Name: 2019-06-01 02:00:00, dtype: float64
# predicted=107.9281622, expected=open    107.715
# Name: 2019-06-01 03:00:00, dtype: float64
# predicted=107.9281622, expected=open    107.668
# Name: 2019-06-01 04:00:00, dtype: float64
# predicted=107.9281619, expected=open    107.666
# Name: 2019-06-01 05:00:00, dtype: float64
# predicted=107.9281619, expected=open    107.682
# Name: 2019-06-01 06:00:00, dtype: float64
# predicted=107.9281621, expected=open    107.662
# Name: 2019-06-01 07:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.608
# Name: 2019-06-01 08:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.688
# Name: 2019-06-01 09:00:00, dtype: float64
# predicted=107.9281627, expected=open    107.612
# Name: 2019-06-01 10:00:00, dtype: float64
# predicted=107.9281626, expected=open    107.616
# Name: 2019-06-01 11:00:00, dtype: float64
# predicted=107.9281624, expected=open    107.574
# Name: 2019-06-01 12:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.668
# Name: 2019-06-01 13:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.588
# Name: 2019-06-01 14:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.538
# Name: 2019-06-01 15:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.672
# Name: 2019-06-01 16:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.676
# Name: 2019-06-01 17:00:00, dtype: float64
# predicted=107.9281624, expected=open    107.81
# Name: 2019-06-01 18:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.841
# Name: 2019-06-01 19:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.802
# Name: 2019-06-01 20:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.889
# Name: 2019-06-01 21:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.836
# Name: 2019-06-01 22:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.833
# Name: 2019-06-01 23:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.817
# Name: 2019-06-02 00:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.75
# Name: 2019-06-02 01:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.771
# Name: 2019-06-02 02:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.744
# Name: 2019-06-02 03:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.722
# Name: 2019-06-02 04:00:00, dtype: float64
# predicted=107.9281624, expected=open    107.682
# Name: 2019-06-02 05:00:00, dtype: float64
# predicted=107.9281624, expected=open    107.68
# Name: 2019-06-02 06:00:00, dtype: float64
# predicted=107.9281624, expected=open    107.75
# Name: 2019-06-02 07:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.83
# Name: 2019-06-02 08:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.843
# Name: 2019-06-02 09:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.915
# Name: 2019-06-02 10:00:00, dtype: float64
# predicted=107.9281623, expected=open    107.948
# Name: 2019-06-02 11:00:00, dtype: float64
# predicted=107.9281623, expected=open    108
00:00, dtype: float64
# predicted=107.9281623, expected=open    108.664
# Name: 2019-08-07 19:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.651
# Name: 2019-08-07 20:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.683
# Name: 2019-08-07 21:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.722
# Name: 2019-08-07 22:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.704
# Name: 2019-08-07 23:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.671
# Name: 2019-08-08 00:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.682
# Name: 2019-08-08 01:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.706
# Name: 2019-08-08 02:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.742
# Name: 2019-08-08 03:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.744
# Name: 2019-08-08 04:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.71
# Name: 2019-08-08 05:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.782
# Name: 2019-08-08 06:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.783
# Name: 2019-08-08 07:00:00, dtype: float64
# predicted=107.9281623, expected=open    108.836
# Name: 2019-08-08 08:00:00, dtype: float64

# %%
# Plot predictions against known values
title = 'Exchange Rates of USD/JPY'
ylabel='Exchange Rates of USD/JPY'
xlabel=''

ax = test.plot(legend=True,figsize=(12,6),title=title)
predictions.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %%
test.mean()
# Out:
# open    108.60693
# dtype: float64

# %%
predictions.mean()
# Out:
# 107.92815932740508

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test, predictions)
print(f'SARIMA(0,1,3)(1,0,1,24) MSE Error: {error:11.10}')
# Out:
# SARIMA(0,1,3)(1,0,1,24) MSE Error: 0.9486659446

# %%
from statsmodels.tools.eval_measures import rmse

error = np.sqrt(mean_squared_error(test, predictions))
print(f'SARIMA(0,1,3)(1,0,1,24) RMSE Error: {error:11.10}')
# Out:
# SARIMA(0,1,3)(1,0,1,24) RMSE Error: 0.9739948381

# %%
model = SARIMAX(df,order=(0,1,3),seasonal_order=(1,0,1,24))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                               open   No. Observations:                 8619
# Model:             SARIMAX(0, 1, 3)x(1, 0, 1, 24)   Log Likelihood                9231.135
# Date:                            Sat, 01 Feb 2020   AIC                         -18450.271
# Time:                                    02:50:48   BIC                         -18407.901
# Sample:                                08-14-2018   HQIC                        -18435.822
#                                      - 08-08-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0062      0.007     -0.832      0.405      -0.021       0.008
# ma.L2         -0.0233      0.008     -2.822      0.005      -0.040      -0.007
# ma.L3         -0.0040      0.009     -0.429      0.668      -0.022       0.014
# ar.S.L24      -0.0748      1.922     -0.039      0.969      -3.843       3.693
# ma.S.L24       0.0701      1.923      0.036      0.971      -3.699       3.839
# sigma2         0.0069   3.03e-05    226.721      0.000       0.007       0.007
# ===================================================================================
# Ljung-Box (Q):                       47.79   Jarque-Bera (JB):            315097.98
# Prob(Q):                              0.19   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -0.78
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start=len(df)
end=len(df) + math.ceil(periods*0.2)
fcast = results.predict(start=start,end=end,dynamic=False,typ='levels').rename('SARIMA(0,1,3)(1,0,1,24) Forecast')

# %%
# Plot predictions against known values
title = 'Exchange rates of USD/JPY'
ylabel='Exchange rates of USD/JPY'
xlabel=''

ax = df.plot(legend=True,figsize=(12,6),title=title)
fcast.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %%
df
# Out:
#                         open
# 2018-08-14 06:00:00  110.687
# 2018-08-14 07:00:00  110.748
# 2018-08-14 08:00:00  110.722
# 2018-08-14 09:00:00  110.633
# 2018-08-14 10:00:00  110.790
# ...                      ...
# 2019-08-08 04:00:00  108.744
# 2019-08-08 05:00:00  108.710
# 2019-08-08 06:00:00  108.782
# 2019-08-08 07:00:00  108.783
# 2019-08-08 08:00:00  108.836
#
# [8619 rows x 1 columns]
